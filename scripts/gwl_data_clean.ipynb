# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv("cleaned_data/zomato_clean_final.csv")

# %%
df.head()
# Out:
#                       name                                            cuisine  \
# 0                 Molecule                           Asian, Chinese, Bar Food
# 1       Kwality Restaurant  North Indian, Chinese, Continental, Biryani, D...
# 2  Muscle Vision Nutrition  Continental, North Indian, Chinese, Sandwich, ...
# 3         Starbucks Coffee                            Cafe, Beverages, Coffee
# 4             Xero Degrees  Pizza, Fast Food, Chinese, Burger, Sandwich, I...
#
#     price                                               link  main_cuisine  \
# 0  1000.0  https://www.zomato.com/gwalior/molecule-lashka...         Asian
# 1   700.0  https://www.zomato.com/gwalior/kwality-restaur...  North Indian
# 2   450.0  https://www.zomato.com/gwalior/muscle-vision-n...   Continental
# 3   900.0  https://www.zomato.com/gwalior/starbucks-coffe...          Cafe
# 4   450.0  https://www.zomato.com/gwalior/xero-degrees-ci...         Pizza
#
#   rating                                     cost_for_two
# 0    4.4  ₹1,000 for two people (approx.) Without alcohol
# 1    4.8                    ₹700 for two people (approx.)
# 2    3.5                    ₹450 for two people (approx.)
# 3    4.4                    ₹900 for two people (approx.)
# 4      4                    ₹450 for two people (approx.)

# %%
# Remove rows where name is missing
df = df[df["name"].notna() & (df["name"].str.strip() != "")]

# %%
# Remove duplicate links (keep first valid row)
df = df.drop_duplicates(subset=["link"], keep="first").reset_index(drop=True)

# %%
df.isnull().sum()
# Out:
# name             0
# cuisine          0
# price           36
# link             0
# main_cuisine     0
# rating           0
# cost_for_two     0
# dtype: int64

# %%
# helpers used by both datasets
def extract_cost(x):
    if pd.isna(x): return np.nan
    s = str(x)
    m = re.search(r"₹\s*([\d,]+)", s)
    if m:
        return int(m.group(1).replace(",", ""))
    m2 = re.search(r"(\d{2,5})", s.replace(",",""))
    return int(m2.group(1)) if m2 else np.nan

df["cost"] = df["cost_for_two"].apply(extract_cost)

# %%
df.isnull().sum()
# Out:
# name             0
# cuisine          0
# price           36
# link             0
# main_cuisine     0
# rating           0
# cost_for_two     0
# cost             0
# dtype: int64

# %%
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')

# %%
df = df.drop(columns=["price", "cost_for_two"], errors="ignore")

# %%
df.head()
# Out:
#                       name                                            cuisine  \
# 0                 Molecule                           Asian, Chinese, Bar Food
# 1       Kwality Restaurant  North Indian, Chinese, Continental, Biryani, D...
# 2  Muscle Vision Nutrition  Continental, North Indian, Chinese, Sandwich, ...
# 3         Starbucks Coffee                            Cafe, Beverages, Coffee
# 4             Xero Degrees  Pizza, Fast Food, Chinese, Burger, Sandwich, I...
#
#                                                 link  main_cuisine  rating  \
# 0  https://www.zomato.com/gwalior/molecule-lashka...         Asian     4.4
# 1  https://www.zomato.com/gwalior/kwality-restaur...  North Indian     4.8
# 2  https://www.zomato.com/gwalior/muscle-vision-n...   Continental     3.5
# 3  https://www.zomato.com/gwalior/starbucks-coffe...          Cafe     4.4
# 4  https://www.zomato.com/gwalior/xero-degrees-ci...         Pizza     4.0
#
#    cost
# 0  1000
# 1   700
# 2   450
# 3   900
# 4   450

# %%
# SAVE CLEAN FILE
df.to_csv("output/zomato_gwl.csv", index=False)

print("CLEANED SHAPE:", df.shape)
# Out:
# CLEANED SHAPE: (501, 6)
